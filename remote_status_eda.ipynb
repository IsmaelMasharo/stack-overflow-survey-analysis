# %%
import pandas as pd
import numpy as np
import seaborn as sns 
import matplotlib.pyplot as plt

from pprint import pprint

# %%
import plotly.express as px
import plotly
import plotly.io as pio
import plotly.graph_objects as go

# %%
pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
dataset = 'survey_report_combined.csv'
df = pd.read_csv(dataset, dtype=object)
df.year = pd.to_datetime(df.year).dt.year
df.original_missing_values_per_row_percentage = df.original_missing_values_per_row_percentage.astype(float)

# %%
df.head()
# Out:
#    year  original_missing_values_per_row_percentage       country  \
# 0  2011                                       18.18        Africa
# 1  2011                                       27.27  Other Europe
# 2  2011                                       45.45         India
# 3  2011                                        9.09       Germany
# 4  2011                                       13.64    Other Asia
#
#                     programming_languages programming_languages_other  \
# 0                              javascript                         NaN
# 1                              java;sql;c                         NaN
# 2                     java;javascript;sql                         NaN
# 3                                    java                     haskell
# 4  java;javascript;css;php;sql;c++;c;perl                         NaN
#
#   years_experience                              occupation    age         os  \
# 0               <2               Web Application Developer   < 20      Linux
# 1            41310                       Server Programmer  25-29  Windows 7
# 2            41435                       Server Programmer  25-29      Linux
# 3            41310                                 Student   < 20      Linux
# 4               11  Executive (VP of Eng., CTO, CIO, etc.)  35-39      Linux
#
#         job_satisfaction company_size want_work_language gender education  \
# 0                    FML         1-25                NaN    NaN       NaN
# 1      So happy it hurts       25-100                NaN    NaN       NaN
# 2                    NaN      100-999                NaN    NaN       NaN
# 3  I enjoy going to work          NaN                NaN    NaN       NaN
# 4      It pays the bills         1-25                NaN    NaN       NaN
#
#   database_desire_work database_worked_with undergrad_major remote_status  \
# 0                  NaN                  NaN             NaN           NaN
# 1                  NaN                  NaN             NaN           NaN
# 2                  NaN                  NaN             NaN           NaN
# 3                  NaN                  NaN             NaN           NaN
# 4                  NaN                  NaN             NaN           NaN
#
#                   industry
# 0               Consulting
# 1        Software Products
# 2        Software Products
# 3  Foundation / Non-Profit
# 4        Software Products

# %%
feature_across_years('undergrad_major')
# Out:
#                                                                                 undergrad_major
# Computer science, computer engineering, or software engineering                          129132
# Information systems, information technology, or system administration                     15831
# Another engineering discipline (ex. civil, electrical, mechanical)                        13167
# Mathematics or statistics                                                                  7642
# Web development or web design                                                              7629
# A natural science (ex. biology, chemistry, physics)                                        6282
# Another engineering discipline (such as civil, electrical, mechanical, etc.)               4754
# A business discipline (ex. accounting, finance, marketing)                                 3762
# A humanities discipline (ex. literature, history, philosophy)                              3161
# A social science (ex. anthropology, psychology, political science)                         2729
# Fine arts or performing arts (ex. graphic design, music, studio art)                       2368
# A natural science (such as biology, chemistry, physics, etc.)                              2205
# I never declared a major                                                                   2122
# A business discipline (such as accounting, finance, marketing, etc.)                       1375
# A humanities discipline (such as literature, history, philosophy, etc.)                    1007
# A social science (such as anthropology, psychology, political science, etc.)                933
# Fine arts or performing arts (such as graphic design, music, studio art, etc.)              725
# A health science (ex. nursing, pharmacy, radiology)                                         569
# A health science (such as nursing, pharmacy, radiology, etc.)                               252
#                                                                                      count  \
# year undergrad_major
# 2018 A business discipline (ex. accounting, finance, marketing)                       1921
#      A health science (ex. nursing, pharmacy, radiology)                               246
#      A humanities discipline (ex. literature, history, philosophy)                    1590
#      A natural science (ex. biology, chemistry, physics)                              3050
#      A social science (ex. anthropology, psychology, political science)               1377
#      Another engineering discipline (ex. civil, electrical, mechanical)               6945
#      Computer science, computer engineering, or software engineering                 50336
#      Fine arts or performing arts (ex. graphic design, music, studio art)             1135
#      I never declared a major                                                          693
#      Information systems, information technology, or system administration            6507
#      Mathematics or statistics                                                        2818
#      Web development or web design                                                    2418
# 2019 A business discipline (ex. accounting, finance, marketing)                       1841
#      A health science (ex. nursing, pharmacy, radiology)                               323
#      A humanities discipline (ex. literature, history, philosophy)                    1571
#      A natural science (ex. biology, chemistry, physics)                              3232
#      A social science (ex. anthropology, psychology, political science)               1352
#      Another engineering discipline (ex. civil, electrical, mechanical)               6222
#      Computer science, computer engineering, or software engineering                 47214
#      Fine arts or performing arts (ex. graphic design, music, studio art)             1233
#      I never declared a major                                                          976
#      Information systems, information technology, or system administration            5253
#      Mathematics or statistics                                                        2975
#      Web development or web design                                                    3422
# 2020 A business discipline (such as accounting, finance, marketing, etc.)             1375
#      A health science (such as nursing, pharmacy, radiology, etc.)                     252
#      A humanities discipline (such as literature, history, philosophy, etc.)          1007
#      A natural science (such as biology, chemistry, physics, etc.)                    2205
#      A social science (such as anthropology, psychology, political science, etc.)      933
#      Another engineering discipline (such as civil, electrical, mechanical, etc.)     4754
#      Computer science, computer engineering, or software engineering                 31582
#      Fine arts or performing arts (such as graphic design, music, studio art, etc.)    725
#      I never declared a major                                                          453
#      Information systems, information technology, or system administration            4071
#      Mathematics or statistics                                                        1849
#      Web development or web design                                                    1789
#
#                                                                                      percentage
# year undergrad_major
# 2018 A business discipline (ex. accounting, finance, marketing)                          0.0243
#      A health science (ex. nursing, pharmacy, radiology)                                 0.0031
#      A humanities discipline (ex. literature, history, philosophy)                       0.0201
#      A natural science (ex. biology, chemistry, physics)                                 0.0386
#      A social science (ex. anthropology, psychology, political science)                  0.0174
#      Another engineering discipline (ex. civil, electrical, mechanical)                  0.0879
#      Computer science, computer engineering, or software engineering                     0.6369
#      Fine arts or performing arts (ex. graphic design, music, studio art)                0.0144
#      I never declared a major                                                            0.0088
#      Information systems, information technology, or system administration               0.0823
#      Mathematics or statistics                                                           0.0357
#      Web development or web design                                                       0.0306
# 2019 A business discipline (ex. accounting, finance, marketing)                          0.0243
#      A health science (ex. nursing, pharmacy, radiology)                                 0.0043
#      A humanities discipline (ex. literature, history, philosophy)                       0.0208
#      A natural science (ex. biology, chemistry, physics)                                 0.0427
#      A social science (ex. anthropology, psychology, political science)                  0.0179
#      Another engineering discipline (ex. civil, electrical, mechanical)                  0.0823
#      Computer science, computer engineering, or software engineering                     0.6244
#      Fine arts or performing arts (ex. graphic design, music, studio art)                0.0163
#      I never declared a major                                                            0.0129
#      Information systems, information technology, or system administration               0.0695
#      Mathematics or statistics                                                           0.0393
#      Web development or web design                                                       0.0453
# 2020 A business discipline (such as accounting, finance, marketing, etc.)                0.0270
#      A health science (such as nursing, pharmacy, radiology, etc.)                       0.0049
#      A humanities discipline (such as literature, history, philosophy, etc.)             0.0197
#      A natural science (such as biology, chemistry, physics, etc.)                       0.0432
#      A social science (such as anthropology, psychology, political science, etc.)        0.0183
#      Another engineering discipline (such as civil, electrical, mechanical, etc.)        0.0932
#      Computer science, computer engineering, or software engineering                     0.6193
#      Fine arts or performing arts (such as graphic design, music, studio art, etc.)      0.0142
#      I never declared a major                                                            0.0089
#      Information systems, information technology, or system administration               0.0798
#      Mathematics or statistics                                                           0.0363
#      Web development or web design                                                       0.0351
